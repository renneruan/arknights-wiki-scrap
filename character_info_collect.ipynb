# %% [markdown]
# <h2>Coleta de dados de Wiki</h2>
#
# Este é um projeto de estudo, o objetivo é aplicar conhecimentos de <em>webscrap</em> para coletar dados dispostos em wikis sobre o jogo Arknights, desenvolvido pela Hypergryph.
#
# O jogo possui uma gama de personagens com diferentes níveis de poder e impacto para o sucesso no mesmo. As wikis consultadas possuem diversas discussões e comentários acerca da utilidade de cada personagem que podem auxiliar na priorização de utilização e evolução.
#
# Origem dos dados: https://arknights.fandom.com/

# %%
# Módulos instalados no ambiente

# pip install requests
# pip install beautifulsoup4

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6,zh-CN;q=0.5,zh;q=0.4",
    "cache-control": "max-age=0",
    "priority": "u=0, i",
    "referer": "https://arknights.fandom.com/wiki/Operator/List",
    "sec-ch-ua": '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36",
}

base_url = "https://arknights.fandom.com/"
response = requests.get(base_url + "wiki/Operator/6-star", headers=headers)
# Resgatando informações de personagens de uma certa raridade para análise inicial

# %%
print(response.status_code)
# response.text # Comentando para prevenir poluir o notebook com todo o conteúdo da página
# Out:
# 200

# %% [markdown]
# A análise do HTML da página foi realizada tanto utilizando o resultado fornecido pelo BeautifulSoup quanto com a utilização do inspecionar no navegador.

# %%
if response.status_code == 200:
    page_html = BeautifulSoup(response.text)
# page_html # Comentado para evitar poluir o notebook

# %% [markdown]
# Inicialmente foi procurado a estrutura a partir do nome dos primeiros personagens, e onde eles possivelmente apareceriam listados. Foi encontrado que os mesmos estavam dispostas em uma estrutura <code>table</code> o que é facilmente identificável ao visualizar a página.

# %%
def get_character_list_data(html_text):
    table_operators = html_text.find("table", class_="sortable")
    table_operators = table_operators.find("tbody")
    table_rows = table_operators.find_all("tr")

    columns_th = table_rows[0].find_all("th")
    columns_names = [column.text for column in columns_th]
    columns_names = columns_names[1:]  # A primeira coluna é a imagem do personagem

    table_data = []

    for row in table_rows[1:]:
        reference_list = row.find_all("a")

        new_element = {}
        # Referenciando as informações de acordo com a ordem das colunas na tabela
        for index, reference in enumerate(reference_list):
            if index == 0:
                new_element["reference"] = reference.attrs["href"]

            new_element[columns_names[index]] = reference.attrs["title"]

        table_data.append(new_element)

    return table_data


get_character_list_data(page_html)
# Out:
# [{'reference': '/wiki/Aak',
#   'Name': 'Aak',
#   'Class': 'Specialist',
#   'Branch': 'Geek',
#   'Faction': "Lee's Detective Agency"},
#  {'reference': '/wiki/Angelina',
#   'Name': 'Angelina',
#   'Class': 'Supporter',
#   'Branch': 'Decel Binder',
#   'Faction': 'Siracusa'},
#  {'reference': '/wiki/Archetto',
#   'Name': 'Archetto',
#   'Class': 'Sniper',
#   'Branch': 'Marksman',
#   'Faction': 'Laterano'},
#  {'reference': '/wiki/Ash',
#   'Name': 'Ash',
#   'Class': 'Sniper',
#   'Branch': 'Marksman',
#   'Faction': 'Team Rainbow'},
#  {'reference': '/wiki/Bagpipe',
#   'Name': 'Bagpipe',
#   'Class': 'Vanguard',
#   'Branch': 'Charger',
#   'Faction': 'Victoria'},
#  {'reference': '/wiki/Blaze',
#   'Name': 'Blaze',
#   'Class': 'Guard',
#   'Branch': 'Centurion',
#   'Faction': 'Elite Op'},
#  {'reference': '/wiki/Blemishine',
#   'Name': 'Blemishine',
#   'Class': 'Defender',
#   'Branch': 'Guardian',
#   'Faction': 'Kazimierz'},
#  {'reference': '/wiki/Carnelian',
#   'Name': 'Carnelian',
#   'Class': 'Caster',
#   'Branch': 'Phalanx',
#   'Faction': 'Leithanien'},
#  {'reference': '/wiki/Ceobe',
#   'Name': 'Ceobe',
#   'Class': 'Caster',
#   'Branch': 'Core',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Ch%27en',
#   'Name': "Ch'en",
#   'Class': 'Guard',
#   'Branch': 'Swordmaster',
#   'Faction': 'Lungmen Guard Department'},
#  {'reference': '/wiki/Ch%27en_the_Holungday',
#   'Name': "Ch'en the Holungday",
#   'Class': 'Sniper',
#   'Branch': 'Spreadshooter',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Chongyue',
#   'Name': 'Chongyue',
#   'Class': 'Guard',
#   'Branch': 'Fighter',
#   'Faction': 'Sui'},
#  {'reference': '/wiki/Dorothy',
#   'Name': 'Dorothy',
#   'Class': 'Specialist',
#   'Branch': 'Trapmaster',
#   'Faction': 'Rhine Lab'},
#  {'reference': '/wiki/Dusk',
#   'Name': 'Dusk',
#   'Class': 'Caster',
#   'Branch': 'Splash',
#   'Faction': 'Sui'},
#  {'reference': '/wiki/Ebenholz',
#   'Name': 'Ebenholz',
#   'Class': 'Caster',
#   'Branch': 'Mystic',
#   'Faction': 'Leithanien'},
#  {'reference': '/wiki/Eunectes',
#   'Name': 'Eunectes',
#   'Class': 'Defender',
#   'Branch': 'Duelist',
#   'Faction': 'Sargon'},
#  {'reference': '/wiki/Executor_the_Ex_Foedere',
#   'Name': 'Executor the Ex Foedere',
#   'Class': 'Guard',
#   'Branch': 'Reaper',
#   'Faction': 'Laterano'},
#  {'reference': '/wiki/Exusiai',
#   'Name': 'Exusiai',
#   'Class': 'Sniper',
#   'Branch': 'Marksman',
#   'Faction': 'Penguin Logistics'},
#  {'reference': '/wiki/Eyjafjalla',
#   'Name': 'Eyjafjalla',
#   'Class': 'Caster',
#   'Branch': 'Core',
#   'Faction': 'Leithanien'},
#  {'reference': '/wiki/Eyjafjalla_the_Hv%C3%ADt_Aska',
#   'Name': 'Eyjafjalla the Hvít Aska',
#   'Class': 'Medic',
#   'Branch': 'Wandering',
#   'Faction': 'Leithanien'},
#  {'reference': '/wiki/Fartooth',
#   'Name': 'Fartooth',
#   'Class': 'Sniper',
#   'Branch': 'Deadeye',
#   'Faction': 'Pinus Sylvestris'},
#  {'reference': '/wiki/Fiammetta',
#   'Name': 'Fiammetta',
#   'Class': 'Sniper',
#   'Branch': 'Artilleryman',
#   'Faction': 'Laterano'},
#  {'reference': '/wiki/Flametail',
#   'Name': 'Flametail',
#   'Class': 'Vanguard',
#   'Branch': 'Pioneer',
#   'Faction': 'Pinus Sylvestris'},
#  {'reference': '/wiki/Gavial_the_Invincible',
#   'Name': 'Gavial the Invincible',
#   'Class': 'Guard',
#   'Branch': 'Centurion',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Gladiia',
#   'Name': 'Gladiia',
#   'Class': 'Specialist',
#   'Branch': 'Hookmaster',
#   'Faction': 'Abyssal Hunters'},
#  {'reference': '/wiki/Gnosis',
#   'Name': 'Gnosis',
#   'Class': 'Supporter',
#   'Branch': 'Hexer',
#   'Faction': 'Karlan Trade'},
#  {'reference': '/wiki/Goldenglow',
#   'Name': 'Goldenglow',
#   'Class': 'Caster',
#   'Branch': 'Mech-Accord',
#   'Faction': 'Victoria'},
#  {'reference': '/wiki/Hellagur',
#   'Name': 'Hellagur',
#   'Class': 'Guard',
#   'Branch': 'Musha',
#   'Faction': 'Ursus'},
#  {'reference': '/wiki/Ho%27olheyak',
#   'Name': "Ho'olheyak",
#   'Class': 'Caster',
#   'Branch': 'Core',
#   'Faction': 'Columbia'},
#  {'reference': '/wiki/Horn',
#   'Name': 'Horn',
#   'Class': 'Defender',
#   'Branch': 'Fortress',
#   'Faction': 'Victoria'},
#  {'reference': '/wiki/Hoshiguma',
#   'Name': 'Hoshiguma',
#   'Class': 'Defender',
#   'Branch': 'Protector',
#   'Faction': 'Lungmen Guard Department'},
#  {'reference': '/wiki/Ifrit',
#   'Name': 'Ifrit',
#   'Class': 'Caster',
#   'Branch': 'Blast',
#   'Faction': 'Rhine Lab'},
#  {'reference': '/wiki/Ines',
#   'Name': 'Ines',
#   'Class': 'Vanguard',
#   'Branch': 'Agent',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Irene',
#   'Name': 'Irene',
#   'Class': 'Guard',
#   'Branch': 'Swordmaster',
#   'Faction': 'Iberia'},
#  {'reference': '/wiki/Jessica_the_Liberated',
#   'Name': 'Jessica the Liberated',
#   'Class': 'Defender',
#   'Branch': 'Sentinel Protector',
#   'Faction': 'Blacksteel'},
#  {'reference': '/wiki/Kal%27tsit',
#   'Name': "Kal'tsit",
#   'Class': 'Medic',
#   'Branch': 'Medic',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Kirin_R_Yato',
#   'Name': 'Kirin R Yato',
#   'Class': 'Specialist',
#   'Branch': 'Executor',
#   'Faction': 'Op A4'},
#  {'reference': '/wiki/Lee',
#   'Name': 'Lee',
#   'Class': 'Specialist',
#   'Branch': 'Merchant',
#   'Faction': "Lee's Detective Agency"},
#  {'reference': '/wiki/Lin',
#   'Name': 'Lin',
#   'Class': 'Caster',
#   'Branch': 'Phalanx',
#   'Faction': 'Lungmen'},
#  {'reference': '/wiki/Ling',
#   'Name': 'Ling',
#   'Class': 'Supporter',
#   'Branch': 'Summoner',
#   'Faction': 'Sui'},
#  {'reference': '/wiki/Lumen',
#   'Name': 'Lumen',
#   'Class': 'Medic',
#   'Branch': 'Therapist',
#   'Faction': 'Iberia'},
#  {'reference': '/wiki/Magallan',
#   'Name': 'Magallan',
#   'Class': 'Supporter',
#   'Branch': 'Summoner',
#   'Faction': 'Rhine Lab'},
#  {'reference': '/wiki/Mizuki',
#   'Name': 'Mizuki',
#   'Class': 'Specialist',
#   'Branch': 'Ambusher',
#   'Faction': 'Higashi'},
#  {'reference': '/wiki/Mostima',
#   'Name': 'Mostima',
#   'Class': 'Caster',
#   'Branch': 'Splash',
#   'Faction': 'Laterano'},
#  {'reference': '/wiki/Mountain',
#   'Name': 'Mountain',
#   'Class': 'Guard',
#   'Branch': 'Fighter',
#   'Faction': 'Columbia'},
#  {'reference': '/wiki/Mudrock',
#   'Name': 'Mudrock',
#   'Class': 'Defender',
#   'Branch': 'Juggernaut',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Muelsyse',
#   'Name': 'Muelsyse',
#   'Class': 'Vanguard',
#   'Branch': 'Tactician',
#   'Faction': 'Rhine Lab'},
#  {'reference': '/wiki/M%C5%82ynar',
#   'Name': 'Młynar',
#   'Class': 'Guard',
#   'Branch': 'Liberator',
#   'Faction': 'Kazimierz'},
#  {'reference': '/wiki/Nearl_the_Radiant_Knight',
#   'Name': 'Nearl the Radiant Knight',
#   'Class': 'Guard',
#   'Branch': 'Dreadnought',
#   'Faction': 'Kazimierz'},
#  {'reference': '/wiki/Nian',
#   'Name': 'Nian',
#   'Class': 'Defender',
#   'Branch': 'Protector',
#   'Faction': 'Sui'},
#  {'reference': '/wiki/Nightingale',
#   'Name': 'Nightingale',
#   'Class': 'Medic',
#   'Branch': 'Multi-target',
#   'Faction': 'Followers'},
#  {'reference': '/wiki/Pallas',
#   'Name': 'Pallas',
#   'Class': 'Guard',
#   'Branch': 'Instructor',
#   'Faction': 'Minos'},
#  {'reference': '/wiki/Passenger',
#   'Name': 'Passenger',
#   'Class': 'Caster',
#   'Branch': 'Chain',
#   'Faction': 'Sargon'},
#  {'reference': '/wiki/Penance',
#   'Name': 'Penance',
#   'Class': 'Defender',
#   'Branch': 'Juggernaut',
#   'Faction': 'Siracusa'},
#  {'reference': '/wiki/Phantom',
#   'Name': 'Phantom',
#   'Class': 'Specialist',
#   'Branch': 'Executor',
#   'Faction': 'Victoria'},
#  {'reference': '/wiki/Poz%C3%ABmka',
#   'Name': 'Pozëmka',
#   'Class': 'Sniper',
#   'Branch': 'Heavyshooter',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Qiubai',
#   'Name': 'Qiubai',
#   'Class': 'Guard',
#   'Branch': 'Lord',
#   'Faction': 'Yan'},
#  {'reference': '/wiki/Reed_the_Flame_Shadow',
#   'Name': 'Reed the Flame Shadow',
#   'Class': 'Medic',
#   'Branch': 'Incantation',
#   'Faction': 'Dublinn'},
#  {'reference': '/wiki/Rosa',
#   'Name': 'Rosa',
#   'Class': 'Sniper',
#   'Branch': 'Besieger',
#   'Faction': 'Ursus Student Self-Governing Group'},
#  {'reference': '/wiki/Rosmontis',
#   'Name': 'Rosmontis',
#   'Class': 'Sniper',
#   'Branch': 'Flinger',
#   'Faction': 'Elite Op'},
#  {'reference': '/wiki/Saga',
#   'Name': 'Saga',
#   'Class': 'Vanguard',
#   'Branch': 'Pioneer',
#   'Faction': 'Higashi'},
#  {'reference': '/wiki/Saileach',
#   'Name': 'Saileach',
#   'Class': 'Vanguard',
#   'Branch': 'Standard Bearer',
#   'Faction': 'Victoria'},
#  {'reference': '/wiki/Saria',
#   'Name': 'Saria',
#   'Class': 'Defender',
#   'Branch': 'Guardian',
#   'Faction': 'Rhine Lab'},
#  {'reference': '/wiki/Schwarz',
#   'Name': 'Schwarz',
#   'Class': 'Sniper',
#   'Branch': 'Heavyshooter',
#   'Faction': 'Siesta'},
#  {'reference': '/wiki/Shining',
#   'Name': 'Shining',
#   'Class': 'Medic',
#   'Branch': 'Medic',
#   'Faction': 'Followers'},
#  {'reference': '/wiki/Siege',
#   'Name': 'Siege',
#   'Class': 'Vanguard',
#   'Branch': 'Pioneer',
#   'Faction': 'Glasgow'},
#  {'reference': '/wiki/Silence_the_Paradigmatic',
#   'Name': 'Silence the Paradigmatic',
#   'Class': 'Supporter',
#   'Branch': 'Abjurer',
#   'Faction': 'Rhine Lab'},
#  {'reference': '/wiki/SilverAsh',
#   'Name': 'SilverAsh',
#   'Class': 'Guard',
#   'Branch': 'Lord',
#   'Faction': 'Karlan Trade'},
#  {'reference': '/wiki/Skadi',
#   'Name': 'Skadi',
#   'Class': 'Guard',
#   'Branch': 'Dreadnought',
#   'Faction': 'Abyssal Hunters'},
#  {'reference': '/wiki/Skadi_the_Corrupting_Heart',
#   'Name': 'Skadi the Corrupting Heart',
#   'Class': 'Supporter',
#   'Branch': 'Bard',
#   'Faction': 'Aegir'},
#  {'reference': '/wiki/Specter_the_Unchained',
#   'Name': 'Specter the Unchained',
#   'Class': 'Specialist',
#   'Branch': 'Dollkeeper',
#   'Faction': 'Abyssal Hunters'},
#  {'reference': '/wiki/Stainless',
#   'Name': 'Stainless',
#   'Class': 'Supporter',
#   'Branch': 'Artificer',
#   'Faction': 'Victoria'},
#  {'reference': '/wiki/Surtr',
#   'Name': 'Surtr',
#   'Class': 'Guard',
#   'Branch': 'Arts Fighter',
#   'Faction': 'Rhodes Island'},
#  {'reference': '/wiki/Suzuran',
#   'Name': 'Suzuran',
#   'Class': 'Supporter',
#   'Branch': 'Decel Binder',
#   'Faction': 'Siracusa'},
#  {'reference': '/wiki/Swire_the_Elegant_Wit',
#   'Name': 'Swire the Elegant Wit',
#   'Class': 'Specialist',
#   'Branch': 'Merchant',
#   'Faction': 'Lungmen'},
#  {'reference': '/wiki/Texas_the_Omertosa',
#   'Name': 'Texas the Omertosa',
#   'Class': 'Specialist',
#   'Branch': 'Executor',
#   'Faction': 'Penguin Logistics'},
#  {'reference': '/wiki/Thorns',
#   'Name': 'Thorns',
#   'Class': 'Guard',
#   'Branch': 'Lord',
#   'Faction': 'Iberia'},
#  {'reference': '/wiki/Typhon',
#   'Name': 'Typhon',
#   'Class': 'Sniper',
#   'Branch': 'Besieger',
#   'Faction': 'Sami'},
#  {'reference': '/wiki/Vigil',
#   'Name': 'Vigil',
#   'Class': 'Vanguard',
#   'Branch': 'Tactician',
#   'Faction': 'Siracusa'},
#  {'reference': '/wiki/W',
#   'Name': 'W',
#   'Class': 'Sniper',
#   'Branch': 'Artilleryman',
#   'Faction': 'Babel'},
#  {'reference': '/wiki/Weedy',
#   'Name': 'Weedy',
#   'Class': 'Specialist',
#   'Branch': 'Push Stroker',
#   'Faction': 'Rhodes Island'}]

# %% [markdown]
# Após essa função temos as informações mais básicas dos personagens de determinada categoria, neste caso personagens marcados como "6 estrelas".

# %%
# Poderia realizar a busca de categorias de forma automática também resgatando de outra página
# Repassando os valores diretos para simplificar pois dificilmente serão adicionadas novas raridades
operator_list_prefix = "wiki/Operator/"
rarity_list = ["6-star", "5-star", "4-star", "3-star", "2-star", "1-star"]


def get_from_rarity_list(prefix, rarity_list):
    all_rarities_list = []
    for rarity in rarity_list:
        # Requisita para a página especifica daquela raridade
        full_url = base_url + prefix + rarity
        response = requests.get(full_url, headers=headers)
        if response.status_code == 200:
            rarity_response = get_character_list_data(BeautifulSoup(response.text))
            for resp in rarity_response:
                resp["rarity"] = rarity

            print(rarity_response)
        else:
            print(f"Requisição não foi completada {response.status_code} para {rarity}")

        all_rarities_list.append(rarity_response)

    return all_rarities_list


data = get_from_rarity_list(operator_list_prefix, rarity_list)
print(data)
# Out:
# [{'reference': '/wiki/Aak', 'Name': 'Aak', 'Class': 'Specialist', 'Branch': 'Geek', 'Faction': "Lee's Detective Agency", 'rarity': '6-star'}, {'reference': '/wiki/Angelina', 'Name': 'Angelina', 'Class': 'Supporter', 'Branch': 'Decel Binder', 'Faction': 'Siracusa', 'rarity': '6-star'}, {'reference': '/wiki/Archetto', 'Name': 'Archetto', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Laterano', 'rarity': '6-star'}, {'reference': '/wiki/Ash', 'Name': 'Ash', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Team Rainbow', 'rarity': '6-star'}, {'reference': '/wiki/Bagpipe', 'Name': 'Bagpipe', 'Class': 'Vanguard', 'Branch': 'Charger', 'Faction': 'Victoria', 'rarity': '6-star'}, {'reference': '/wiki/Blaze', 'Name': 'Blaze', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': 'Elite Op', 'rarity': '6-star'}, {'reference': '/wiki/Blemishine', 'Name': 'Blemishine', 'Class': 'Defender', 'Branch': 'Guardian', 'Faction': 'Kazimierz', 'rarity': '6-star'}, {'reference': '/wiki/Carnelian', 'Name': 'Carnelian', 'Class': 'Caster', 'Branch': 'Phalanx', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Ceobe', 'Name': 'Ceobe', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Rhodes Island', 'rarity': '6-star'}, {'reference': '/wiki/Ch%27en', 'Name': "Ch'en", 'Class': 'Guard', 'Branch': 'Swordmaster', 'Faction': 'Lungmen Guard Department', 'rarity': '6-star'}, {'reference': '/wiki/Ch%27en_the_Holungday', 'Name': "Ch'en the Holungday", 'Class': 'Sniper', 'Branch': 'Spreadshooter', 'Faction': 'Rhodes Island', 'rarity': '6-star'}, {'reference': '/wiki/Chongyue', 'Name': 'Chongyue', 'Class': 'Guard', 'Branch': 'Fighter', 'Faction': 'Sui', 'rarity': '6-star'}, {'reference': '/wiki/Dorothy', 'Name': 'Dorothy', 'Class': 'Specialist', 'Branch': 'Trapmaster', 'Faction': 'Rhine Lab', 'rarity': '6-star'}, {'reference': '/wiki/Dusk', 'Name': 'Dusk', 'Class': 'Caster', 'Branch': 'Splash', 'Faction': 'Sui', 'rarity': '6-star'}, {'reference': '/wiki/Ebenholz', 'Name': 'Ebenholz', 'Class': 'Caster', 'Branch': 'Mystic', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Eunectes', 'Name': 'Eunectes', 'Class': 'Defender', 'Branch': 'Duelist', 'Faction': 'Sargon', 'rarity': '6-star'}, {'reference': '/wiki/Executor_the_Ex_Foedere', 'Name': 'Executor the Ex Foedere', 'Class': 'Guard', 'Branch': 'Reaper', 'Faction': 'Laterano', 'rarity': '6-star'}, {'reference': '/wiki/Exusiai', 'Name': 'Exusiai', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Penguin Logistics', 'rarity': '6-star'}, {'reference': '/wiki/Eyjafjalla', 'Name': 'Eyjafjalla', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Eyjafjalla_the_Hv%C3%ADt_Aska', 'Name': 'Eyjafjalla the Hvít Aska', 'Class': 'Medic', 'Branch': 'Wandering', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Fartooth', 'Name': 'Fartooth', 'Class': 'Sniper', 'Branch': 'Deadeye', 'Faction': 'Pinus Sylvestris', 'rarity': '6-star'}, {'reference': '/wiki/Fiammetta', 'Name': 'Fiammetta', 'Class': 'Sniper', 'Branch': 'Artilleryman', 'Faction': 'Laterano', 'rarity': '6-star'}, {'reference': '/wiki/Flametail', 'Name': 'Flametail', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': 'Pinus Sylvestris', 'rarity': '6-star'}, {'reference': '/wiki/Gavial_the_Invincible', 'Name': 'Gavial the Invincible', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': 'Rhodes Island', 'rarity': '6-star'}, {'reference': '/wiki/Gladiia', 'Name': 'Gladiia', 'Class': 'Specialist', 'Branch': 'Hookmaster', 'Faction': 'Abyssal Hunters', 'rarity': '6-star'}, {'reference': '/wiki/Gnosis', 'Name': 'Gnosis', 'Class': 'Supporter', 'Branch': 'Hexer', 'Faction': 'Karlan Trade', 'rarity': '6-star'}, {'reference': '/wiki/Goldenglow', 'Name': 'Goldenglow', 'Class': 'Caster', 'Branch': 'Mech-Accord', 'Faction': 'Victoria', 'rarity': '6-star'}, {'reference': '/wiki/Hellagur', 'Name': 'Hellagur', 'Class': 'Guard', 'Branch': 'Musha', 'Faction': 'Ursus', 'rarity':  ...
# [{'reference': '/wiki/Absinthe', 'Name': 'Absinthe', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Ursus', 'rarity': '5-star'}, {'reference': '/wiki/Akafuyu', 'Name': 'Akafuyu', 'Class': 'Guard', 'Branch': 'Musha', 'Faction': 'Higashi', 'rarity': '5-star'}, {'reference': '/wiki/Almond', 'Name': 'Almond', 'Class': 'Specialist', 'Branch': 'Hookmaster', 'Faction': 'Blacksteel', 'rarity': '5-star'}, {'reference': '/wiki/Amiya', 'Name': 'Amiya', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Rhodes Island', 'rarity': '5-star'}, {'reference': '/wiki/Andreana', 'Name': 'Andreana', 'Class': 'Sniper', 'Branch': 'Deadeye', 'Faction': 'Abyssal Hunters', 'rarity': '5-star'}, {'reference': '/wiki/Aosta', 'Name': 'Aosta', 'Class': 'Sniper', 'Branch': 'Spreadshooter', 'Faction': "Chiave's Gang", 'rarity': '5-star'}, {'reference': '/wiki/April', 'Name': 'April', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Rim Billiton', 'rarity': '5-star'}, {'reference': '/wiki/Asbestos', 'Name': 'Asbestos', 'Class': 'Defender', 'Branch': 'Arts Protector', 'Faction': 'Rim Billiton', 'rarity': '5-star'}, {'reference': '/wiki/Ashlock', 'Name': 'Ashlock', 'Class': 'Defender', 'Branch': 'Fortress', 'Faction': 'Pinus Sylvestris', 'rarity': '5-star'}, {'reference': '/wiki/Astesia', 'Name': 'Astesia', 'Class': 'Guard', 'Branch': 'Arts Fighter', 'Faction': 'Columbia', 'rarity': '5-star'}, {'reference': '/wiki/Astgenne', 'Name': 'Astgenne', 'Class': 'Caster', 'Branch': 'Chain', 'Faction': 'Rhine Lab', 'rarity': '5-star'}, {'reference': '/wiki/Aurora', 'Name': 'Aurora', 'Class': 'Defender', 'Branch': 'Duelist', 'Faction': 'Karlan Trade', 'rarity': '5-star'}, {'reference': '/wiki/Ayerscarpe', 'Name': 'Ayerscarpe', 'Class': 'Guard', 'Branch': 'Lord', 'Faction': 'Rim Billiton', 'rarity': '5-star'}, {'reference': '/wiki/Beeswax', 'Name': 'Beeswax', 'Class': 'Caster', 'Branch': 'Phalanx', 'Faction': 'Sargon', 'rarity': '5-star'}, {'reference': '/wiki/Bena', 'Name': 'Bena', 'Class': 'Specialist', 'Branch': 'Dollkeeper', 'Faction': 'Victoria', 'rarity': '5-star'}, {'reference': '/wiki/Bibeak', 'Name': 'Bibeak', 'Class': 'Guard', 'Branch': 'Swordmaster', 'Faction': 'Sami', 'rarity': '5-star'}, {'reference': '/wiki/Bison', 'Name': 'Bison', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Lungmen', 'rarity': '5-star'}, {'reference': '/wiki/Blacknight', 'Name': 'Blacknight', 'Class': 'Vanguard', 'Branch': 'Tactician', 'Faction': 'Rim Billiton', 'rarity': '5-star'}, {'reference': '/wiki/Blitz', 'Name': 'Blitz', 'Class': 'Defender', 'Branch': 'Sentinel Protector', 'Faction': 'Team Rainbow', 'rarity': '5-star'}, {'reference': '/wiki/Blue_Poison', 'Name': 'Blue Poison', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Iberia', 'rarity': '5-star'}, {'reference': '/wiki/Breeze', 'Name': 'Breeze', 'Class': 'Medic', 'Branch': 'Multi-target', 'Faction': 'Victoria', 'rarity': '5-star'}, {'reference': '/wiki/Broca', 'Name': 'Broca', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': "Chiave's Gang", 'rarity': '5-star'}, {'reference': '/wiki/Bryophyta', 'Name': 'Bryophyta', 'Class': 'Guard', 'Branch': 'Instructor', 'Faction': 'Siesta', 'rarity': '5-star'}, {'reference': '/wiki/Cantabile', 'Name': 'Cantabile', 'Class': 'Vanguard', 'Branch': 'Agent', 'Faction': 'Rhodes Island', 'rarity': '5-star'}, {'reference': '/wiki/Cement', 'Name': 'Cement', 'Class': 'Defender', 'Branch': 'Duelist', 'Faction': 'Rim Billiton', 'rarity': '5-star'}, {'reference': '/wiki/Ceylon', 'Name': 'Ceylon', 'Class': 'Medic', 'Branch': 'Therapist', 'Faction': 'Siesta', 'rarity': '5-star'}, {'reference': '/wiki/Chiave', 'Name': 'Chiave', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': "Chiave's Gang", 'rarity': '5-star'}, {'reference': '/wiki/Cliffheart', 'Name': 'Cliffheart', 'Class': 'Specialist', 'Branch': 'Hookmaster', 'Faction': 'Karlan Trade', 'rarity': '5-star'}, {'reference': '/wiki/Coldshot', 'Name': 'Coldshot', 'Class': 'Sniper', 'Branch': 'Hunter', 'Faction': 'Columbia', 'rarity': ...
# [{'reference': '/wiki/Aciddrop', 'Name': 'Aciddrop', 'Class': 'Sniper', 'Branch': 'Heavyshooter', 'Faction': 'Columbia', 'rarity': '4-star'}, {'reference': '/wiki/Ambriel', 'Name': 'Ambriel', 'Class': 'Sniper', 'Branch': 'Deadeye', 'Faction': 'Laterano', 'rarity': '4-star'}, {'reference': '/wiki/Arene', 'Name': 'Arene', 'Class': 'Guard', 'Branch': 'Lord', 'Faction': 'Laterano', 'rarity': '4-star'}, {'reference': '/wiki/Beanstalk', 'Name': 'Beanstalk', 'Class': 'Vanguard', 'Branch': 'Tactician', 'Faction': 'Columbia', 'rarity': '4-star'}, {'reference': '/wiki/Beehunter', 'Name': 'Beehunter', 'Class': 'Guard', 'Branch': 'Fighter', 'Faction': 'Ursus', 'rarity': '4-star'}, {'reference': '/wiki/Bubble', 'Name': 'Bubble', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Sargon', 'rarity': '4-star'}, {'reference': '/wiki/Chestnut', 'Name': 'Chestnut', 'Class': 'Medic', 'Branch': 'Wandering', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Click', 'Name': 'Click', 'Class': 'Caster', 'Branch': 'Mech-Accord', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Conviction', 'Name': 'Conviction', 'Class': 'Guard', 'Branch': 'Dreadnought', 'Faction': 'Minos', 'rarity': '4-star'}, {'reference': '/wiki/Courier', 'Name': 'Courier', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': 'Karlan Trade', 'rarity': '4-star'}, {'reference': '/wiki/Cuora', 'Name': 'Cuora', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Columbia', 'rarity': '4-star'}, {'reference': '/wiki/Cutter', 'Name': 'Cutter', 'Class': 'Guard', 'Branch': 'Swordmaster', 'Faction': 'Columbia', 'rarity': '4-star'}, {'reference': '/wiki/Deepcolor', 'Name': 'Deepcolor', 'Class': 'Supporter', 'Branch': 'Summoner', 'Faction': 'Aegir', 'rarity': '4-star'}, {'reference': '/wiki/Dobermann', 'Name': 'Dobermann', 'Class': 'Guard', 'Branch': 'Instructor', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Dur-nar', 'Name': 'Dur-nar', 'Class': 'Defender', 'Branch': 'Arts Protector', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Earthspirit', 'Name': 'Earthspirit', 'Class': 'Supporter', 'Branch': 'Decel Binder', 'Faction': 'Leithanien', 'rarity': '4-star'}, {'reference': '/wiki/Estelle', 'Name': 'Estelle', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': 'Sargon', 'rarity': '4-star'}, {'reference': '/wiki/Ethan', 'Name': 'Ethan', 'Class': 'Specialist', 'Branch': 'Ambusher', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Frostleaf', 'Name': 'Frostleaf', 'Class': 'Guard', 'Branch': 'Lord', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Gavial', 'Name': 'Gavial', 'Class': 'Medic', 'Branch': 'Medic', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Gitano', 'Name': 'Gitano', 'Class': 'Caster', 'Branch': 'Splash', 'Faction': 'Sami', 'rarity': '4-star'}, {'reference': '/wiki/Gravel', 'Name': 'Gravel', 'Class': 'Specialist', 'Branch': 'Executor', 'Faction': 'Kazimierz', 'rarity': '4-star'}, {'reference': '/wiki/Greyy', 'Name': 'Greyy', 'Class': 'Caster', 'Branch': 'Splash', 'Faction': 'Bolívar', 'rarity': '4-star'}, {'reference': '/wiki/Gummy', 'Name': 'Gummy', 'Class': 'Defender', 'Branch': 'Guardian', 'Faction': 'Ursus Student Self-Governing Group', 'rarity': '4-star'}, {'reference': '/wiki/Haze', 'Name': 'Haze', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Victoria', 'rarity': '4-star'}, {'reference': '/wiki/Humus', 'Name': 'Humus', 'Class': 'Guard', 'Branch': 'Reaper', 'Faction': 'Rhodes Island', 'rarity': '4-star'}, {'reference': '/wiki/Indigo', 'Name': 'Indigo', 'Class': 'Caster', 'Branch': 'Mystic', 'Faction': 'Iberia', 'rarity': '4-star'}, {'reference': '/wiki/Jackie', 'Name': 'Jackie', 'Class': 'Guard', 'Branch': 'Fighter', 'Faction': 'Columbia', 'rarity': '4-star'}, {'reference': '/wiki/Jaye', 'Name': 'Jaye', 'Class': 'Specialist', 'Branch': 'Merchant', 'Faction': 'Lungmen', 'rarity': '4-star'}, {'reference': '/wiki/Jessi ...
# [{'reference': '/wiki/Adnachiel', 'Name': 'Adnachiel', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Op Reserve A4', 'rarity': '3-star'}, {'reference': '/wiki/Ansel', 'Name': 'Ansel', 'Class': 'Medic', 'Branch': 'Medic', 'Faction': 'Op Reserve A4', 'rarity': '3-star'}, {'reference': '/wiki/Beagle', 'Name': 'Beagle', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Op Reserve A1', 'rarity': '3-star'}, {'reference': '/wiki/Cardigan', 'Name': 'Cardigan', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Op Reserve A4', 'rarity': '3-star'}, {'reference': '/wiki/Catapult', 'Name': 'Catapult', 'Class': 'Sniper', 'Branch': 'Artilleryman', 'Faction': 'Op Reserve A6', 'rarity': '3-star'}, {'reference': '/wiki/Fang', 'Name': 'Fang', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': 'Op Reserve A1', 'rarity': '3-star'}, {'reference': '/wiki/Hibiscus', 'Name': 'Hibiscus', 'Class': 'Medic', 'Branch': 'Medic', 'Faction': 'Op Reserve A1', 'rarity': '3-star'}, {'reference': '/wiki/Kroos', 'Name': 'Kroos', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Op Reserve A1', 'rarity': '3-star'}, {'reference': '/wiki/Lava', 'Name': 'Lava', 'Class': 'Caster', 'Branch': 'Splash', 'Faction': 'Op Reserve A1', 'rarity': '3-star'}, {'reference': '/wiki/Melantha', 'Name': 'Melantha', 'Class': 'Guard', 'Branch': 'Dreadnought', 'Faction': 'Op Reserve A4', 'rarity': '3-star'}, {'reference': '/wiki/Midnight', 'Name': 'Midnight', 'Class': 'Guard', 'Branch': 'Lord', 'Faction': 'Op Reserve A6', 'rarity': '3-star'}, {'reference': '/wiki/Orchid', 'Name': 'Orchid', 'Class': 'Supporter', 'Branch': 'Decel Binder', 'Faction': 'Op Reserve A6', 'rarity': '3-star'}, {'reference': '/wiki/Plume', 'Name': 'Plume', 'Class': 'Vanguard', 'Branch': 'Charger', 'Faction': 'Laterano', 'rarity': '3-star'}, {'reference': '/wiki/Popukar', 'Name': 'Popukar', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': 'Op Reserve A6', 'rarity': '3-star'}, {'reference': '/wiki/Spot', 'Name': 'Spot', 'Class': 'Defender', 'Branch': 'Guardian', 'Faction': 'Op Reserve A6', 'rarity': '3-star'}, {'reference': '/wiki/Steward', 'Name': 'Steward', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Op Reserve A4', 'rarity': '3-star'}, {'reference': '/wiki/Vanilla', 'Name': 'Vanilla', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': 'Blacksteel', 'rarity': '3-star'}]
# [{'reference': '/wiki/12F', 'Name': '12F', 'Class': 'Caster', 'Branch': 'Splash', 'Faction': 'Rhodes Island', 'rarity': '2-star'}, {'reference': '/wiki/Durin', 'Name': 'Durin', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Op A4', 'rarity': '2-star'}, {'reference': '/wiki/Noir_Corne', 'Name': 'Noir Corne', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Op A4', 'rarity': '2-star'}, {'reference': '/wiki/Rangers', 'Name': 'Rangers', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Op A4', 'rarity': '2-star'}, {'reference': '/wiki/Yato', 'Name': 'Yato', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': 'Op A4', 'rarity': '2-star'}]
# [{'reference': '/wiki/Castle-3', 'Name': 'Castle-3', 'Class': 'Guard', 'Branch': 'Dreadnought', 'Faction': 'Rhodes Island', 'rarity': '1-star'}, {'reference': '/wiki/Friston-3', 'Name': 'Friston-3', 'Class': 'Defender', 'Branch': 'Protector', 'Faction': 'Rhodes Island', 'rarity': '1-star'}, {'reference': '/wiki/Justice_Knight', 'Name': 'Justice Knight', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Pinus Sylvestris', 'rarity': '1-star'}, {'reference': '/wiki/Lancet-2', 'Name': 'Lancet-2', 'Class': 'Medic', 'Branch': 'Medic', 'Faction': 'Rhodes Island', 'rarity': '1-star'}, {'reference': '/wiki/THRM-EX', 'Name': 'THRM-EX', 'Class': 'Specialist', 'Branch': 'Executor', 'Faction': 'Rhodes Island', 'rarity': '1-star'}, {'reference': '/wiki/Terra_Research_Commission', 'Name': 'Terra Research Commission', 'Class': 'Sniper', 'Branch': 'Flinger', 'Faction': 'Rhodes Island', 'rarity': '1-star'}, {'reference': '/wiki/U-Official', 'Name': 'U-Official', 'Class': 'Supporter', 'Branch': 'Bard', 'Faction': 'Rhodes Island', 'rarity': '1-star'}]
# [[{'reference': '/wiki/Aak', 'Name': 'Aak', 'Class': 'Specialist', 'Branch': 'Geek', 'Faction': "Lee's Detective Agency", 'rarity': '6-star'}, {'reference': '/wiki/Angelina', 'Name': 'Angelina', 'Class': 'Supporter', 'Branch': 'Decel Binder', 'Faction': 'Siracusa', 'rarity': '6-star'}, {'reference': '/wiki/Archetto', 'Name': 'Archetto', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Laterano', 'rarity': '6-star'}, {'reference': '/wiki/Ash', 'Name': 'Ash', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Team Rainbow', 'rarity': '6-star'}, {'reference': '/wiki/Bagpipe', 'Name': 'Bagpipe', 'Class': 'Vanguard', 'Branch': 'Charger', 'Faction': 'Victoria', 'rarity': '6-star'}, {'reference': '/wiki/Blaze', 'Name': 'Blaze', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': 'Elite Op', 'rarity': '6-star'}, {'reference': '/wiki/Blemishine', 'Name': 'Blemishine', 'Class': 'Defender', 'Branch': 'Guardian', 'Faction': 'Kazimierz', 'rarity': '6-star'}, {'reference': '/wiki/Carnelian', 'Name': 'Carnelian', 'Class': 'Caster', 'Branch': 'Phalanx', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Ceobe', 'Name': 'Ceobe', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Rhodes Island', 'rarity': '6-star'}, {'reference': '/wiki/Ch%27en', 'Name': "Ch'en", 'Class': 'Guard', 'Branch': 'Swordmaster', 'Faction': 'Lungmen Guard Department', 'rarity': '6-star'}, {'reference': '/wiki/Ch%27en_the_Holungday', 'Name': "Ch'en the Holungday", 'Class': 'Sniper', 'Branch': 'Spreadshooter', 'Faction': 'Rhodes Island', 'rarity': '6-star'}, {'reference': '/wiki/Chongyue', 'Name': 'Chongyue', 'Class': 'Guard', 'Branch': 'Fighter', 'Faction': 'Sui', 'rarity': '6-star'}, {'reference': '/wiki/Dorothy', 'Name': 'Dorothy', 'Class': 'Specialist', 'Branch': 'Trapmaster', 'Faction': 'Rhine Lab', 'rarity': '6-star'}, {'reference': '/wiki/Dusk', 'Name': 'Dusk', 'Class': 'Caster', 'Branch': 'Splash', 'Faction': 'Sui', 'rarity': '6-star'}, {'reference': '/wiki/Ebenholz', 'Name': 'Ebenholz', 'Class': 'Caster', 'Branch': 'Mystic', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Eunectes', 'Name': 'Eunectes', 'Class': 'Defender', 'Branch': 'Duelist', 'Faction': 'Sargon', 'rarity': '6-star'}, {'reference': '/wiki/Executor_the_Ex_Foedere', 'Name': 'Executor the Ex Foedere', 'Class': 'Guard', 'Branch': 'Reaper', 'Faction': 'Laterano', 'rarity': '6-star'}, {'reference': '/wiki/Exusiai', 'Name': 'Exusiai', 'Class': 'Sniper', 'Branch': 'Marksman', 'Faction': 'Penguin Logistics', 'rarity': '6-star'}, {'reference': '/wiki/Eyjafjalla', 'Name': 'Eyjafjalla', 'Class': 'Caster', 'Branch': 'Core', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Eyjafjalla_the_Hv%C3%ADt_Aska', 'Name': 'Eyjafjalla the Hvít Aska', 'Class': 'Medic', 'Branch': 'Wandering', 'Faction': 'Leithanien', 'rarity': '6-star'}, {'reference': '/wiki/Fartooth', 'Name': 'Fartooth', 'Class': 'Sniper', 'Branch': 'Deadeye', 'Faction': 'Pinus Sylvestris', 'rarity': '6-star'}, {'reference': '/wiki/Fiammetta', 'Name': 'Fiammetta', 'Class': 'Sniper', 'Branch': 'Artilleryman', 'Faction': 'Laterano', 'rarity': '6-star'}, {'reference': '/wiki/Flametail', 'Name': 'Flametail', 'Class': 'Vanguard', 'Branch': 'Pioneer', 'Faction': 'Pinus Sylvestris', 'rarity': '6-star'}, {'reference': '/wiki/Gavial_the_Invincible', 'Name': 'Gavial the Invincible', 'Class': 'Guard', 'Branch': 'Centurion', 'Faction': 'Rhodes Island', 'rarity': '6-star'}, {'reference': '/wiki/Gladiia', 'Name': 'Gladiia', 'Class': 'Specialist', 'Branch': 'Hookmaster', 'Faction': 'Abyssal Hunters', 'rarity': '6-star'}, {'reference': '/wiki/Gnosis', 'Name': 'Gnosis', 'Class': 'Supporter', 'Branch': 'Hexer', 'Faction': 'Karlan Trade', 'rarity': '6-star'}, {'reference': '/wiki/Goldenglow', 'Name': 'Goldenglow', 'Class': 'Caster', 'Branch': 'Mech-Accord', 'Faction': 'Victoria', 'rarity': '6-star'}, {'reference': '/wiki/Hellagur', 'Name': 'Hellagur', 'Class': 'Guard', 'Branch': 'Musha', 'Faction': 'Ursus', 'rarity': ...

# %% [markdown]
# Agora temos a uma lista de listas, contendo todos os personagens de diferentes raridades. Em seguida foi utilizado apenas um compressor de listas para tornar a lista em uma única dimensão com o registro de todos os personagens.

# %%
flat_data = [element for elements in data for element in elements]

flat_data
len(flat_data)
# Out:
# 296
